# %%
import sys
sys.path.append("../..")
sys.path.append("../../..")

# %%
import pandas as pd
import utility

# %% [markdown]
# ##### read fixed mutation data

# %%
fixed_mutation_sheet = pd.read_excel('../../../data/fixed_mutation.xlsx', sheet_name='Sheet1')
fixed_mutation_sheet
# Out:
#           CHROM  Position REF ALT refrence allele   up stream  down stram  \
# 0      2-micron       141   C   T               C  GCGAGACAAA  AGGACAATTA
# 1      2-micron      2576   T   C               T  GTGACCTTTG  ATTGACAAAT
# 2      2-micron      2986   G   A               G  CTTAATACAA  CAAGCAGTCT
# 3      2-micron      3082   T   C               T  TACAGAAGGT  TTCGCGGTTT
# 4      2-micron      4525   G   A               G  CGCATACTTT  TGAACAGAAA
# ...         ...       ...  ..  ..             ...         ...         ...
# 25694    chrXVI    851553   A   T               A  GTATATGTTG  GCAAGTGTGT
# 25695    chrXVI    867714   G   A               G  TTGTCTTCGT  GTCGAATCTA
# 25696    chrXVI    898887   C   A               C  GGCCTATGAC  CGCTGGAACA
# 25697    chrXVI    941276   G   T               G  AAATGGGTTT  TTCACGCCAT
# 25698    chrXVI    946291   C   A               C  CTACCACTGC  AGCATCAACG
#
#        file_name      QUAL  SVTYPE  ... LOH_fixed_by_10150 present_at_10150  \
# 0            NaN  23994.97     NaN  ...                0.0                1
# 1            NaN  22083.79     NaN  ...                1.0                1
# 2            NaN  24140.52     NaN  ...                1.0                1
# 3            NaN  25546.51     NaN  ...                1.0                1
# 4            NaN  21905.18     NaN  ...                1.0                1
# ...          ...       ...     ...  ...                ...              ...
# 25694        NaN    386.35     NaN  ...                1.0                1
# 25695        NaN    506.66     NaN  ...                0.0                1
# 25696        NaN   1715.24     NaN  ...                0.0                1
# 25697        NaN    831.57     NaN  ...                0.0                1
# 25698        NaN   2535.90     NaN  ...                0.0                0
#
#                     ID  mutation_group  group_mutation_type  \
# 0       2-micron_141_T               1            noncoding
# 1      2-micron_2576_C               2             missense
# 2      2-micron_2986_A               3             missense
# 3      2-micron_3082_C               4            noncoding
# 4      2-micron_4525_A               6            noncoding
# ...                ...             ...                  ...
# 25694  chrXVI_851553_T             200             missense
# 25695  chrXVI_867714_A             201           synonymous
# 25696  chrXVI_898887_A             202             missense
# 25697  chrXVI_941276_T             203            noncoding
# 25698  chrXVI_946291_A             204           synonymous
#
#        group_mutation_impact  in_telomere              ref_flank  \
# 0                        NaN            0  GCGAGACAAACAGGACAATTA
# 1                   MODERATE            0  GTGACCTTTGTATTGACAAAT
# 2                   MODERATE            0  CTTAATACAAGCAAGCAGTCT
# 3                   MODIFIER            0  TACAGAAGGTTTTCGCGGTTT
# 4                        NaN            0  CGCATACTTTGTGAACAGAAA
# ...                      ...          ...                    ...
# 25694               MODERATE            0  GTATATGTTGAGCAAGTGTGT
# 25695                    LOW            0  TTGTCTTCGTGGTCGAATCTA
# 25696               MODERATE            0  GGCCTATGACCCGCTGGAACA
# 25697                    NaN            0  AAATGGGTTTGTTCACGCCAT
# 25698                    LOW            1  CTACCACTGCCAGCATCAACG
#
#                    alt_flank  population_name
# 0      GCGAGACAAATAGGACAATTA            P3C07
# 1      GTGACCTTTGCATTGACAAAT            P3C07
# 2      CTTAATACAAACAAGCAGTCT            P3C07
# 3      TACAGAAGGTCTTCGCGGTTT            P3C07
# 4      CGCATACTTTATGAACAGAAA            P3C07
# ...                      ...              ...
# 25694  GTATATGTTGTGCAAGTGTGT            P2F09
# 25695  TTGTCTTCGTAGTCGAATCTA            P2F09
# 25696  GGCCTATGACACGCTGGAACA            P2F09
# 25697  AAATGGGTTTTTTCACGCCAT            P2F09
# 25698  CTACCACTGCAAGCATCAACG            P2F09
#
# [25699 rows x 62 columns]

# %%
# fixed_mutation_sheet.drop_duplicates()

# %% [markdown]
# ##### read gain sheet

# %%
ag_sheet = pd.read_csv("yeast_evolved_genome_metadata.csv")
ag_sheet
# Out:
#         Position     CHROM REF ALT population_name  G70_ref_counts  \
# 0             31   chrVIII   C   A           P3G06              35
# 1             34  2-micron   G   T           P1E04              74
# 2             34     chrII   G   A           P2C06               4
# 3             36     chrIX   C   A           P2F11              24
# 4             36     chrIX   C   A           P3F11              44
# ...          ...       ...  ..  ..             ...             ...
# 133529   1525964     chrIV   C   T           P3G10               0
# 133530   1525964     chrIV   C   T           P3G11               2
# 133531   1525998     chrIV   T   C           P3B07               0
# 133532   1525998     chrIV   T   C           P3B10               0
# 133533   1526031     chrIV   A   G           P3D05               0
#
#         G1410_ref_counts  G2640_ref_counts  G5150_ref_counts  \
# 0                     31                59                38
# 1                    104                 3                 0
# 2                      0                 1                 0
# 3                      5                39                 2
# 4                      1                38                 4
# ...                  ...               ...               ...
# 133529                 0                 0                 1
# 133530                 0                 1                 1
# 133531                 0                 1                 1
# 133532                 0                 0                 4
# 133533                 0                 0                 2
#
#         G7530_ref_counts  G10150_ref_counts  G70_alt_counts  G1410_alt_counts  \
# 0                     42                 56               0                 0
# 1                      0                  1               0               217
# 2                      2                  1               0                 0
# 3                     34                  2               0                 0
# 4                     18                  2               0                 0
# ...                  ...                ...             ...               ...
# 133529                 2                  0               3                 5
# 133530                 0                  0               0                 0
# 133531                 3                  0               2                 0
# 133532                 2                  1               0                 0
# 133533                 0                  1               0                 0
#
#         G2640_alt_counts  G5150_alt_counts  G7530_alt_counts  \
# 0                      0                 0                11
# 1                    426               323               156
# 2                      0                 0                16
# 3                      0                 0                 5
# 4                      0                 0                 9
# ...                  ...               ...               ...
# 133529                12                 7                18
# 133530                 6                 0                 4
# 133531                 0                 1                 8
# 133532                 3                 2                 0
# 133533                 0                 0                32
#
#         G10150_alt_counts  accumulate_gain  kGain_evolved_genome
# 0                       0        -3.577119             -3.577119
# 1                     236         0.392871              0.392871
# 2                      12        -4.563850             -4.311335
# 3                       0       -11.012777            -11.012777
# 4                       0       -11.012777            -11.012777
# ...                   ...              ...                   ...
# 133529                  0         8.835324              8.835324
# 133530                  0         8.835324              8.835324
# 133531                  0       -14.496006            -14.496006
# 133532                  0       -14.496006            -14.719149
# 133533                  6        -5.155277             -5.206571
#
# [133534 rows x 19 columns]

# %%
# ag_sheet.drop_duplicates()

# %%
# ag_sheet = pd.read_excel('../../../data/fixed_mutation(1).xlsx', sheet_name='Sheet2')
# ag_sheet

# %% [markdown]
# ##### Merge gain and fixed count dataframes on common columns

# %%
merged_df = pd.merge(fixed_mutation_sheet, ag_sheet[['CHROM', 'Position', 'REF', 'ALT', 'population_name', 'accumulate_gain', "kGain_evolved_genome"]], 
                     on=['CHROM', 'Position', 'REF', 'ALT', 'population_name'], 
                     how='left')

# %%
merged_df
# Out:
#           CHROM  Position REF ALT refrence allele   up stream  down stram  \
# 0      2-micron       141   C   T               C  GCGAGACAAA  AGGACAATTA
# 1      2-micron      2576   T   C               T  GTGACCTTTG  ATTGACAAAT
# 2      2-micron      2986   G   A               G  CTTAATACAA  CAAGCAGTCT
# 3      2-micron      3082   T   C               T  TACAGAAGGT  TTCGCGGTTT
# 4      2-micron      4525   G   A               G  CGCATACTTT  TGAACAGAAA
# ...         ...       ...  ..  ..             ...         ...         ...
# 25694    chrXVI    851553   A   T               A  GTATATGTTG  GCAAGTGTGT
# 25695    chrXVI    867714   G   A               G  TTGTCTTCGT  GTCGAATCTA
# 25696    chrXVI    898887   C   A               C  GGCCTATGAC  CGCTGGAACA
# 25697    chrXVI    941276   G   T               G  AAATGGGTTT  TTCACGCCAT
# 25698    chrXVI    946291   C   A               C  CTACCACTGC  AGCATCAACG
#
#        file_name      QUAL  SVTYPE  ...               ID mutation_group  \
# 0            NaN  23994.97     NaN  ...   2-micron_141_T              1
# 1            NaN  22083.79     NaN  ...  2-micron_2576_C              2
# 2            NaN  24140.52     NaN  ...  2-micron_2986_A              3
# 3            NaN  25546.51     NaN  ...  2-micron_3082_C              4
# 4            NaN  21905.18     NaN  ...  2-micron_4525_A              6
# ...          ...       ...     ...  ...              ...            ...
# 25694        NaN    386.35     NaN  ...  chrXVI_851553_T            200
# 25695        NaN    506.66     NaN  ...  chrXVI_867714_A            201
# 25696        NaN   1715.24     NaN  ...  chrXVI_898887_A            202
# 25697        NaN    831.57     NaN  ...  chrXVI_941276_T            203
# 25698        NaN   2535.90     NaN  ...  chrXVI_946291_A            204
#
#        group_mutation_type  group_mutation_impact  in_telomere  \
# 0                noncoding                    NaN            0
# 1                 missense               MODERATE            0
# 2                 missense               MODERATE            0
# 3                noncoding               MODIFIER            0
# 4                noncoding                    NaN            0
# ...                    ...                    ...          ...
# 25694             missense               MODERATE            0
# 25695           synonymous                    LOW            0
# 25696             missense               MODERATE            0
# 25697            noncoding                    NaN            0
# 25698           synonymous                    LOW            1
#
#                    ref_flank              alt_flank  population_name  \
# 0      GCGAGACAAACAGGACAATTA  GCGAGACAAATAGGACAATTA            P3C07
# 1      GTGACCTTTGTATTGACAAAT  GTGACCTTTGCATTGACAAAT            P3C07
# 2      CTTAATACAAGCAAGCAGTCT  CTTAATACAAACAAGCAGTCT            P3C07
# 3      TACAGAAGGTTTTCGCGGTTT  TACAGAAGGTCTTCGCGGTTT            P3C07
# 4      CGCATACTTTGTGAACAGAAA  CGCATACTTTATGAACAGAAA            P3C07
# ...                      ...                    ...              ...
# 25694  GTATATGTTGAGCAAGTGTGT  GTATATGTTGTGCAAGTGTGT            P2F09
# 25695  TTGTCTTCGTGGTCGAATCTA  TTGTCTTCGTAGTCGAATCTA            P2F09
# 25696  GGCCTATGACCCGCTGGAACA  GGCCTATGACACGCTGGAACA            P2F09
# 25697  AAATGGGTTTGTTCACGCCAT  AAATGGGTTTTTTCACGCCAT            P2F09
# 25698  CTACCACTGCCAGCATCAACG  CTACCACTGCAAGCATCAACG            P2F09
#
#        accumulate_gain  kGain_evolved_genome
# 0             0.460847              0.460847
# 1            -2.585438             -2.585438
# 2             6.325886              6.325886
# 3            -4.901611             -4.901611
# 4             1.634026              1.634026
# ...                ...                   ...
# 25694        -4.976722             -4.976722
# 25695         2.969015              2.969015
# 25696         1.565519              1.565519
# 25697         5.688471              5.688471
# 25698       -12.010930            -12.010930
#
# [25699 rows x 64 columns]

# %% [markdown]
# ##### Evolved kGain vs generation with fixation status as hue

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['ps.fonttype'] = 42

columns_for_box_plot = ['fixed_by_70', 'fixed_by_1410', 'fixed_by_2640', 'fixed_by_5150', 'fixed_by_7530', 'fixed_by_10150']
merged_df[columns_for_box_plot] = merged_df[columns_for_box_plot].astype(int)
df_melted = pd.melt(merged_df, id_vars=['kGain_evolved_genome'], value_vars=columns_for_box_plot, var_name='Mutation_Type', value_name='Fixed')
df_melted['Fixed'] = df_melted['Fixed'].replace({0: "False", 1: "True"})
df_melted =  df_melted.drop_duplicates()
# df_melted = df_melted.dropna()
df_melted['generation_number'] = (
    df_melted['Mutation_Type']
    .str.extract(r'_(\d+)$')[0]   # <--- Extracts numbers after the last underscore at the end
    .astype('Int64')
)

fig, ax = plt.subplots(1,1, figsize = (4.2, 4.2), dpi =300)

data = df_melted.copy()
x_column = "Mutation_Type"
y_column = 'kGain_evolved_genome'
hue_column= "Fixed"
group1_name = 'True'
group2_name = 'False'
ax = sns.boxplot(data=data, x=x_column, y= y_column, hue = hue_column,     fliersize=2,         # reduce outlier dot size
    linewidth=0.25,         # box line thickness
    width=0.75,  
    meanprops={"marker":"o",
               "markerfacecolor":"black",
               "markeredgecolor":"black",
               "markersize":"5"},
    palette="Set2",
    dodge=True 
)
ax = utility.return_box_with_p_effect_size(ax=ax, data = data, x_columns = x_column, y_columns = y_column, group1_name = group1_name, group2_name = group2_name, y_pos = 22,  fontsize=3, hue_columns=hue_column)
# ax.set_title("Synonymus")
ax.set_ylabel("kGain")
ax.set_xlabel("Mutation type")
ax = utility.custom_figure_axis(ax, fontsize= 8, rotation=45)
ax.legend(ncol = 2, frameon=False, fontsize= 8)
# Improve tick label font size and make sure ticks show
ax.tick_params(axis='x', which='both', labelsize=8, bottom=True, top=False, direction='out')
ax.tick_params(axis='y', which='both', labelsize=8, left=True, right=False, direction='out')

ax.set_ylim(-35, 30)

plt.tight_layout()
# plt.savefig("kGain vs mutator type with synonymus mutation type.pdf", dpi =300)
# Out:
# P-value = 1.73e-01 and effect size = 1.09e-01 for fixed_by_70,
# P-value = 5.32e-02 and effect size = 1.19e-01 for fixed_by_1410,
# P-value = 4.71e-03 and effect size = 9.49e-02 for fixed_by_2640,
# P-value = 3.25e-03 and effect size = 8.53e-02 for fixed_by_5150,
# P-value = 2.72e-03 and effect size = 6.00e-02 for fixed_by_7530,
# P-value = 1.03e-03 and effect size = 6.08e-02 for fixed_by_10150,
