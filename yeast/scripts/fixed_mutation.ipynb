# %%
import pandas as pd

# %% [markdown]
# ##### read fixed mutation data

# %%
fixed_mutation_sheet = pd.read_excel('/home/abhishekh/Downloads/fixed_mutation(1).xlsx', sheet_name='Sheet1')
fixed_mutation_sheet
# Out:
#           CHROM  Position REF ALT refrence allele   up stream  down stram  \
# 0      2-micron       141   C   T               C  GCGAGACAAA  AGGACAATTA
# 1      2-micron      2576   T   C               T  GTGACCTTTG  ATTGACAAAT
# 2      2-micron      2986   G   A               G  CTTAATACAA  CAAGCAGTCT
# 3      2-micron      3082   T   C               T  TACAGAAGGT  TTCGCGGTTT
# 4      2-micron      4525   G   A               G  CGCATACTTT  TGAACAGAAA
# ...         ...       ...  ..  ..             ...         ...         ...
# 25694    chrXVI    851553   A   T               A  GTATATGTTG  GCAAGTGTGT
# 25695    chrXVI    867714   G   A               G  TTGTCTTCGT  GTCGAATCTA
# 25696    chrXVI    898887   C   A               C  GGCCTATGAC  CGCTGGAACA
# 25697    chrXVI    941276   G   T               G  AAATGGGTTT  TTCACGCCAT
# 25698    chrXVI    946291   C   A               C  CTACCACTGC  AGCATCAACG
#
#        file_name      QUAL  SVTYPE  ... LOH_fixed_by_10150 present_at_10150  \
# 0            NaN  23994.97     NaN  ...                0.0                1
# 1            NaN  22083.79     NaN  ...                1.0                1
# 2            NaN  24140.52     NaN  ...                1.0                1
# 3            NaN  25546.51     NaN  ...                1.0                1
# 4            NaN  21905.18     NaN  ...                1.0                1
# ...          ...       ...     ...  ...                ...              ...
# 25694        NaN    386.35     NaN  ...                1.0                1
# 25695        NaN    506.66     NaN  ...                0.0                1
# 25696        NaN   1715.24     NaN  ...                0.0                1
# 25697        NaN    831.57     NaN  ...                0.0                1
# 25698        NaN   2535.90     NaN  ...                0.0                0
#
#                     ID  mutation_group  group_mutation_type  \
# 0       2-micron_141_T               1            noncoding
# 1      2-micron_2576_C               2             missense
# 2      2-micron_2986_A               3             missense
# 3      2-micron_3082_C               4            noncoding
# 4      2-micron_4525_A               6            noncoding
# ...                ...             ...                  ...
# 25694  chrXVI_851553_T             200             missense
# 25695  chrXVI_867714_A             201           synonymous
# 25696  chrXVI_898887_A             202             missense
# 25697  chrXVI_941276_T             203            noncoding
# 25698  chrXVI_946291_A             204           synonymous
#
#        group_mutation_impact  in_telomere              ref_flank  \
# 0                        NaN            0  GCGAGACAAACAGGACAATTA
# 1                   MODERATE            0  GTGACCTTTGTATTGACAAAT
# 2                   MODERATE            0  CTTAATACAAGCAAGCAGTCT
# 3                   MODIFIER            0  TACAGAAGGTTTTCGCGGTTT
# 4                        NaN            0  CGCATACTTTGTGAACAGAAA
# ...                      ...          ...                    ...
# 25694               MODERATE            0  GTATATGTTGAGCAAGTGTGT
# 25695                    LOW            0  TTGTCTTCGTGGTCGAATCTA
# 25696               MODERATE            0  GGCCTATGACCCGCTGGAACA
# 25697                    NaN            0  AAATGGGTTTGTTCACGCCAT
# 25698                    LOW            1  CTACCACTGCCAGCATCAACG
#
#                    alt_flank  population_name
# 0      GCGAGACAAATAGGACAATTA            P3C07
# 1      GTGACCTTTGCATTGACAAAT            P3C07
# 2      CTTAATACAAACAAGCAGTCT            P3C07
# 3      TACAGAAGGTCTTCGCGGTTT            P3C07
# 4      CGCATACTTTATGAACAGAAA            P3C07
# ...                      ...              ...
# 25694  GTATATGTTGTGCAAGTGTGT            P2F09
# 25695  TTGTCTTCGTAGTCGAATCTA            P2F09
# 25696  GGCCTATGACACGCTGGAACA            P2F09
# 25697  AAATGGGTTTTTTCACGCCAT            P2F09
# 25698  CTACCACTGCAAGCATCAACG            P2F09
#
# [25699 rows x 62 columns]

# %% [markdown]
# ##### read gain sheet

# %%
ag_sheet = pd.read_excel('/home/abhishekh/Downloads/fixed_mutation(1).xlsx', sheet_name='Sheet2')
ag_sheet
# Out:
#        Min log_likelihood_gain  Position     CHROM REF ALT  \
# 0                    -1.223775       141  2-micron   C   T
# 1                    -0.810930      2576  2-micron   T   C
# 2                     0.000000      2986  2-micron   G   A
# 3                    -1.417066      3082  2-micron   T   C
# 4                    -0.656780      4525  2-micron   G   A
# ...                        ...       ...       ...  ..  ..
# 25227                -0.802346    851553    chrXVI   A   T
# 25228                -0.367725    867714    chrXVI   G   A
# 25229                -1.386294    898887    chrXVI   C   A
# 25230                 0.048790    941276    chrXVI   G   T
# 25231                -1.845827    946291    chrXVI   C   A
#
#       group_mutation_type population_name  G70_ref_counts  G1410_ref_counts  \
# 0               noncoding           P3C07             107                 0
# 1                missense           P3C07             107                 0
# 2                missense           P3C07             107                 0
# 3               noncoding           P3C07             107                 0
# 4               noncoding           P3C07             107                 0
# ...                   ...             ...             ...               ...
# 25227            missense           P2F09               0                 0
# 25228          synonymous           P2F09              49                36
# 25229            missense           P2F09              47                30
# 25230           noncoding           P2F09              59                36
# 25231          synonymous           P2F09              69                21
#
#        G2640_ref_counts  ...  G7530_ref_counts  G10150_ref_counts  \
# 0                     4  ...                 5                  0
# 1                     5  ...                 1                  0
# 2                     3  ...                 3                  0
# 3                     4  ...                 5                  0
# 4                    10  ...                 2                  0
# ...                 ...  ...               ...                ...
# 25227                 0  ...                 0                  0
# 25228                50  ...                54                 24
# 25229                27  ...                16                 15
# 25230                60  ...                69                 22
# 25231                47  ...                45                283
#
#        G70_alt_counts  G1410_alt_counts  G2640_alt_counts  G5150_alt_counts  \
# 0                   0                 8                22                18
# 1                   0                11                13                16
# 2                   0                 9                13                14
# 3                   0                12                18                24
# 4                   0                 9                25                12
# ...               ...               ...               ...               ...
# 25227               0                 0                 0                 0
# 25228               0                 0                 0                 0
# 25229               0                 0                 8                17
# 25230               0                 0                 0                 0
# 25231               0                15                 0                11
#
#        G7530_alt_counts  G10150_alt_counts  accumulate_gain  \
# 0                    20                  2         0.460847
# 1                    15                  0        -2.585438
# 2                    20                  7         6.325886
# 3                     6                 10        -4.901611
# 4                     7                  5         1.634026
# ...                 ...                ...              ...
# 25227                 0                 13        -4.976722
# 25228                 0                 17         2.969015
# 25229                28                  8         1.565519
# 25230                 0                 27         5.688471
# 25231                 0                  0       -12.010930
#
#        Max log_likelihood_gain
# 0                     0.875469
# 1                     0.000000
# 2                     1.232144
# 3                     0.405465
# 4                     0.777705
# ...                        ...
# 25227                -0.223144
# 25228                 1.098612
# 25229                 1.098612
# 25230                 1.280934
# 25231                -0.693147
#
# [25232 rows x 21 columns]

# %% [markdown]
# ##### Merge gain and fixed count dataframes on common columns

# %%
merged_df = pd.merge(fixed_mutation_sheet, ag_sheet[['CHROM', 'Position', 'REF', 'ALT', 'population_name', 'group_mutation_type', 'accumulate_gain']], 
                     on=['CHROM', 'Position', 'REF', 'ALT', 'population_name', 'group_mutation_type'], 
                     how='left')

# %%
merged_df
# Out:
#           CHROM  Position REF ALT refrence allele   up stream  down stram  \
# 0      2-micron       141   C   T               C  GCGAGACAAA  AGGACAATTA
# 1      2-micron      2576   T   C               T  GTGACCTTTG  ATTGACAAAT
# 2      2-micron      2986   G   A               G  CTTAATACAA  CAAGCAGTCT
# 3      2-micron      3082   T   C               T  TACAGAAGGT  TTCGCGGTTT
# 4      2-micron      4525   G   A               G  CGCATACTTT  TGAACAGAAA
# ...         ...       ...  ..  ..             ...         ...         ...
# 25694    chrXVI    851553   A   T               A  GTATATGTTG  GCAAGTGTGT
# 25695    chrXVI    867714   G   A               G  TTGTCTTCGT  GTCGAATCTA
# 25696    chrXVI    898887   C   A               C  GGCCTATGAC  CGCTGGAACA
# 25697    chrXVI    941276   G   T               G  AAATGGGTTT  TTCACGCCAT
# 25698    chrXVI    946291   C   A               C  CTACCACTGC  AGCATCAACG
#
#        file_name      QUAL  SVTYPE  ... present_at_10150               ID  \
# 0            NaN  23994.97     NaN  ...                1   2-micron_141_T
# 1            NaN  22083.79     NaN  ...                1  2-micron_2576_C
# 2            NaN  24140.52     NaN  ...                1  2-micron_2986_A
# 3            NaN  25546.51     NaN  ...                1  2-micron_3082_C
# 4            NaN  21905.18     NaN  ...                1  2-micron_4525_A
# ...          ...       ...     ...  ...              ...              ...
# 25694        NaN    386.35     NaN  ...                1  chrXVI_851553_T
# 25695        NaN    506.66     NaN  ...                1  chrXVI_867714_A
# 25696        NaN   1715.24     NaN  ...                1  chrXVI_898887_A
# 25697        NaN    831.57     NaN  ...                1  chrXVI_941276_T
# 25698        NaN   2535.90     NaN  ...                0  chrXVI_946291_A
#
#        mutation_group  group_mutation_type  group_mutation_impact  \
# 0                   1            noncoding                    NaN
# 1                   2             missense               MODERATE
# 2                   3             missense               MODERATE
# 3                   4            noncoding               MODIFIER
# 4                   6            noncoding                    NaN
# ...               ...                  ...                    ...
# 25694             200             missense               MODERATE
# 25695             201           synonymous                    LOW
# 25696             202             missense               MODERATE
# 25697             203            noncoding                    NaN
# 25698             204           synonymous                    LOW
#
#        in_telomere              ref_flank              alt_flank  \
# 0                0  GCGAGACAAACAGGACAATTA  GCGAGACAAATAGGACAATTA
# 1                0  GTGACCTTTGTATTGACAAAT  GTGACCTTTGCATTGACAAAT
# 2                0  CTTAATACAAGCAAGCAGTCT  CTTAATACAAACAAGCAGTCT
# 3                0  TACAGAAGGTTTTCGCGGTTT  TACAGAAGGTCTTCGCGGTTT
# 4                0  CGCATACTTTGTGAACAGAAA  CGCATACTTTATGAACAGAAA
# ...            ...                    ...                    ...
# 25694            0  GTATATGTTGAGCAAGTGTGT  GTATATGTTGTGCAAGTGTGT
# 25695            0  TTGTCTTCGTGGTCGAATCTA  TTGTCTTCGTAGTCGAATCTA
# 25696            0  GGCCTATGACCCGCTGGAACA  GGCCTATGACACGCTGGAACA
# 25697            0  AAATGGGTTTGTTCACGCCAT  AAATGGGTTTTTTCACGCCAT
# 25698            1  CTACCACTGCCAGCATCAACG  CTACCACTGCAAGCATCAACG
#
#        population_name  accumulate_gain
# 0                P3C07         0.460847
# 1                P3C07        -2.585438
# 2                P3C07         6.325886
# 3                P3C07        -4.901611
# 4                P3C07         1.634026
# ...                ...              ...
# 25694            P2F09        -4.976722
# 25695            P2F09         2.969015
# 25696            P2F09         1.565519
# 25697            P2F09         5.688471
# 25698            P2F09       -12.010930
#
# [25699 rows x 63 columns]

# %% [markdown]
# ##### Reshape dataframe for box plot

# %%
# Columns for box plot
columns_for_box_plot = ['fixed_by_70', 'fixed_by_1410', 'fixed_by_2640', 'fixed_by_5150', 'fixed_by_7530', 'fixed_by_10150']

# Convert True to 1 and False to 0
merged_df[columns_for_box_plot] = merged_df[columns_for_box_plot].astype(int)

# Melt the DataFrame for box plot
df_melted = pd.melt(merged_df, id_vars=['accumulate_gain'], value_vars=columns_for_box_plot, var_name='Mutation Type', value_name='Fixed')

# %%
df_melted['Fixed'] = df_melted['Fixed'].replace({0: "False", 1: "True"})

# %%
df_melted
# Out:
#         accumulate_gain   Mutation Type  Fixed
# 0              0.460847     fixed_by_70  False
# 1             -2.585438     fixed_by_70  False
# 2              6.325886     fixed_by_70  False
# 3             -4.901611     fixed_by_70  False
# 4              1.634026     fixed_by_70  False
# ...                 ...             ...    ...
# 154189        -4.976722  fixed_by_10150   True
# 154190         2.969015  fixed_by_10150   True
# 154191         1.565519  fixed_by_10150  False
# 154192         5.688471  fixed_by_10150   True
# 154193       -12.010930  fixed_by_10150  False
#
# [154194 rows x 3 columns]

# %%
# import numpy as np
# np.array_equal(np.array(merged_df[['fixed_by_10150']]).ravel(), np.array(df_melted[df_melted.loc[:, "Mutation Type"]=="fixed_by_10150"][['Fixed']]).ravel())

# %%
def custom_figure_axis(ax, fontsize=10, show_ticks = True, rotation=90):
    
        
    """
    Customize the appearance of matplotlib axis for a figure.
    
    Parameters:
        ax (matplotlib.axes._subplots.AxesSubplot): The axis to be customized.
        fontsize (int, optional): Font size for axis labels and ticks. Default is 10.
        show_ticks (bool, optional): Whether to display ticks and labels. Default is True.
    
    Returns:
        matplotlib.axes._subplots.AxesSubplot: The customized axis.
    """
    ax.spines['bottom'].set_color('black')
    ax.spines['left'].set_color('black')
    ax.spines['top'].set_color('white')
    ax.spines['right'].set_color('white')
    ax.grid(False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_linewidth(0.2)
    ax.spines['left'].set_linewidth(0.2)
    ax.tick_params(axis='x', labelsize=fontsize, rotation=rotation)
    ax.tick_params(axis='y', labelsize=fontsize)
    ax.tick_params(axis='both', which='both', width=0.5)
    ax.xaxis.label.set_fontsize(fontsize)
    ax.yaxis.label.set_fontsize(fontsize)
    
    if show_ticks==False:
        ax.set_xlabel(None)
        ax.set_ylabel(None)
        ax.set_xticklabels([])
        ax.set_yticklabels([])
        
    return ax

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 1, dpi = 600, figsize=(1,1))

ax = sns.boxplot(df_melted, y="accumulate_gain", x = "Mutation Type", hue = "Fixed", ax=ax, boxprops=dict(edgecolor="black", linewidth=0),flierprops=dict(marker='o', markeredgecolor='black'), width=0.4,linewidth=0.5, fliersize=0.15, dodge=True,  medianprops={"color": "black","linewidth":0.5})
ax= custom_figure_axis(ax, fontsize=3)
ax.legend(ncol = 2, fontsize=2, frameon=False)
ax.set_ylabel("kGain")
# Out:
# /home/abhishekh/anaconda3/envs/amr/lib/python3.10/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/abhishekh/anaconda3/envs/amr/lib/python3.10/site-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# /home/abhishekh/anaconda3/envs/amr/lib/python3.10/site-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /home/abhishekh/anaconda3/envs/amr/lib/python3.10/site-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Text(0, 0.5, 'kGain')

# %%
def man_whiteney(group1, group2):   
    
    """
    Perform a one-sided Mann-Whitney U test and return the p-value.
    
    This function compares two independent groups and tests if 'group1' tends to have larger values than 'group2'.
    
    Parameters:
        group1 (array-like): The data of the first group.
        group2 (array-like): The data of the second group.
    
    Returns:
        float: The p-value from the one-sided Mann-Whitney U test.
    
    Notes:
        The null hypothesis is that the distribution of 'group1' is not greater than 'group2'.
    """

    from scipy.stats import mannwhitneyu
    statistic, p_value = mannwhitneyu(group1, group2, alternative='greater', nan_policy = "omit")
    return p_value

# %% [markdown]
# ##### Find generation wise p value

# %%
# tmp = pd

for i in set(df_melted["Mutation Type"]):

    tmp = df_melted[df_melted.loc[:, "Mutation Type"]==i]

    print("The one sided Mann-Whitney of  generation " + i + " is" + str(man_whiteney(tmp[tmp.loc[:, "Fixed"]=="True"]["accumulate_gain"], tmp[tmp.loc[:, "Fixed"]=="False"]["accumulate_gain"])))
# Out:
# The one sided Mann-Whitney of  generation fixed_by_5150 is0.0016369263156367025
# The one sided Mann-Whitney of  generation fixed_by_1410 is0.03188925206092693
# The one sided Mann-Whitney of  generation fixed_by_2640 is0.00238463283807234
# The one sided Mann-Whitney of  generation fixed_by_10150 is0.00046802296607905504
# The one sided Mann-Whitney of  generation fixed_by_7530 is0.001030949030906248
# The one sided Mann-Whitney of  generation fixed_by_70 is0.16623128307670126
